# %%
#課題1
x=[0.7501]
for i in range(0,100):
    x.append(4*x[i]*(1-x[i]))
for i in range(0,101):
    if i%10--0:
        print(i,',',x[i])
# Out:
# 1 , 0.74979996
# 2 , 0.7503999199359935
# 3 , 0.7491995203841921
# 4 , 0.7515983961611544
# 5 , 0.7467929881965392
# 6 , 0.7563728839080915
# 7 , 0.7370917775865928
# 8 , 0.7751499560033184
# 9 , 0.6971700068454878
# 11 , 0.5252901518068401
# 12 , 0.9974416328863479
# 13 , 0.010207287485455508
# 14 , 0.04041239507057909
# 15 , 0.1551169335809541
# 16 , 0.5242226819895839
# 17 , 0.997653046708926
# 18 , 0.009365780405294222
# 19 , 0.037112250250776115
# 21 , 0.49003183872057915
# 22 , 0.9996025430428299
# 23 , 0.001589195940549123
# 24 , 0.006346681587246661
# 25 , 0.025225604880307062
# 26 , 0.09835709495491876
# 27 , 0.3547319073077914
# 28 , 0.9155887249822715
# 29 , 0.3091440466704396
# 31 , 0.4978973199567799
# 32 , 0.9999823149465433
# 33 , 7.073896278222909e-05
# 34 , 0.00028293583512549437
# 35 , 0.0011314231297547847
# 36 , 0.004520572045824962
# 37 , 0.018000545896813873
# 38 , 0.07070610497692228
# 39 , 0.2628270067836589
# 41 , 0.6975090525908197
# 42 , 0.8439606965787072
# ...
